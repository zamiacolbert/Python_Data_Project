# %%
# Importing Libraries
import pandas as pd
from datasets import load_dataset
import matplotlib.pyplot as plt 

# Loading Data
dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()

# Data Cleanup
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])

# %% [markdown]
# ## .sample()

# %%
df.sample()
#.head() and .tail() can give us the firsst and last rows respectively, but .sample give a sample 
# which is more representative of the data
# Out:
#           job_title_short         job_title           job_location  \
# 248251  Software Engineer  Support Engineer  Auckland, New Zealand
#
#                      job_via job_schedule_type  job_work_from_home  \
# 248251  via Jobs Trabajo.org         Full-time               False
#
#        search_location     job_posted_date  job_no_degree_mention  \
# 248251     New Zealand 2023-11-23 07:28:36                   True
#
#         job_health_insurance  job_country salary_rate  salary_year_avg  \
# 248251                 False  New Zealand        None              NaN
#
#         salary_hour_avg company_name  \
# 248251              NaN        Aiven
#
#                                                job_skills  \
# 248251  ['python', 'postgresql', 'mysql', 'redis', 'el...
#
#                                           job_type_skills
# 248251  {'databases': ['postgresql', 'mysql', 'redis',...

# %%
df.sample(10)
#everytime .sample() is run, it will return new jobs within the sample
# Out:
#               job_title_short                                      job_title  \
# 408251          Data Engineer                                  Data Engineer
# 537525      Software Engineer                              Software Engineer
# 490622           Data Analyst                                   Data Analyst
# 394513           Data Analyst                                   Data Analyst
# 58931   Senior Data Scientist                  Senior Data Management Expert
# 758431          Data Engineer  Data Operation & Platform Management Engineer
# 207753    Senior Data Analyst                Director, Sr. Lead Data Analyst
# 489487          Data Engineer                              AWS Data Engineer
# 66485            Data Analyst                                   Data Analyst
# 85640    Senior Data Engineer                           Senior Data Engineer
#
#                        job_location  \
# 408251              Lillers, France
# 537525             Grenoble, France
# ...

# %%
df.sample(10, random_state=42)
#with the random_state the same result will return everytime
# Out:
#               job_title_short  \
# 502901   Senior Data Engineer
# 406337  Senior Data Scientist
# 659951          Data Engineer
# 541593           Data Analyst
# 425158   Senior Data Engineer
# 183426           Data Analyst
# 287790           Data Analyst
# 541983           Data Analyst
# 416896         Data Scientist
# 780907          Data Engineer
#
#                                                 job_title  \
# 502901                               Senior Data Engineer
# 406337                          Senior Analytics Engineer
# 659951                                      Data Engineer
# 541593                                       Data Analyst
# 425158  Senior Data Engineer. Job in Amsterdam NBC4i Jobs
# 183426                                       Data Analyst
# 287790                                       Data Analyst
# 541983                   Data Analyst, Cloud Systems Jobs
# 416896             Alternant Actuariat & Data Science H/F
# ...

# %% [markdown]
# ## .copy()

# %%
dataset = load_dataset('lukebarousse/data_jobs')
df_original = dataset['train'].to_pandas()

# %%
df_original
# Out:
#              job_title_short  \
# 0       Senior Data Engineer
# 1               Data Analyst
# 2              Data Engineer
# 3              Data Engineer
# 4              Data Engineer
# ...                      ...
# 785736     Software Engineer
# 785737          Data Analyst
# 785738      Business Analyst
# 785739         Data Engineer
# 785740     Software Engineer
#
#                                                 job_title  \
# 0       Senior Clinical Data Engineer / Principal Clin...
# 1                                            Data Analyst
# 2       Data Engineer/Scientist/Analyst, Mid or Senior...
# 3       LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4                                  Data Engineer- Sr Jobs
# ...                                                   ...
# 785736                                    DevOps Engineer
# 785737                                   CRM Data Analyst
# 785738                     Commercial Analyst - Start Now
# ...

# %%
df_altered = df_original

# %%
df_altered
# Out:
#              job_title_short  \
# 0       Senior Data Engineer
# 1               Data Analyst
# 2              Data Engineer
# 3              Data Engineer
# 4              Data Engineer
# ...                      ...
# 785736     Software Engineer
# 785737          Data Analyst
# 785738      Business Analyst
# 785739         Data Engineer
# 785740     Software Engineer
#
#                                                 job_title  \
# 0       Senior Clinical Data Engineer / Principal Clin...
# 1                                            Data Analyst
# 2       Data Engineer/Scientist/Analyst, Mid or Senior...
# 3       LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4                                  Data Engineer- Sr Jobs
# ...                                                   ...
# 785736                                    DevOps Engineer
# 785737                                   CRM Data Analyst
# 785738                     Commercial Analyst - Start Now
# ...

# %%
df_altered.loc[:5, 'salary_year_avg']
# Out:
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN
# 5   NaN
# Name: salary_year_avg, dtype: float64

# %%
median_salary = df_altered[ 'salary_year_avg'].median()
median_salary
# Out:
# 115000.0

# %%
df_altered[ 'salary_year_avg'] = df_altered[ 'salary_year_avg'].fillna(median_salary)
df_altered.loc[:5, 'salary_year_avg']
# Out:
# 0    115000.0
# 1    115000.0
# 2    115000.0
# 3    115000.0
# 4    115000.0
# 5    115000.0
# Name: salary_year_avg, dtype: float64

# %%
df_original.loc[:5, 'salary_year_avg']
# Out:
# 0    115000.0
# 1    115000.0
# 2    115000.0
# 3    115000.0
# 4    115000.0
# 5    115000.0
# Name: salary_year_avg, dtype: float64

# %% [markdown]
# The original dataframe was altered along with the altered dataframe. This is because when df_altered = df_original, df_orginal id became the df_altered's id

# %%
id(df_original)
# Out:
# 1589680958096

# %%
id(df_altered)
# Out:
# 1589680958096

# %%
id(df_original) == id(df_altered)
# Out:
# True

# %%
dataset = load_dataset('lukebarousse/data_jobs')
df_original = dataset['train'].to_pandas()

# %%
df_altered = df_original.copy()

# %%
print('ID of df_original:               ', id(df_original))
print('ID of df_altered:                ', id(df_altered))
print('Are the two dataframes the same? ', id(df_original) == id(df_altered))
# Out:
# ID of df_original:                1590030671312
# ID of df_altered:                 1589681072528
# Are the two dataframes the same?  False

# %%
median_salary = df_altered['salary_year_avg'].median()

df_altered['salary_year_avg'] = df_altered['salary_year_avg'].fillna(median_salary)

df_altered.loc[:5,'salary_year_avg']
# Out:
# 0    115000.0
# 1    115000.0
# 2    115000.0
# 3    115000.0
# 4    115000.0
# 5    115000.0
# Name: salary_year_avg, dtype: float64

# %%
df_original.loc[:5,'salary_year_avg']
# Out:
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN
# 5   NaN
# Name: salary_year_avg, dtype: float64

# %% [markdown]
# ---

# %% [markdown]
# # Course Practice Problems

# %% [markdown]
# Create a copy of the DataFrame and drop rows where the salary_year_avg column has missing values. Display the first 5 rows of the cleaned DataFrame. (2.3.1)
#
#     Use the copy() method to create a copy of the DataFrame and the dropna() method to drop rows with missing values.

# %%
dataset = load_dataset('lukebarousse/data_jobs')
df_original = dataset['train'].to_pandas()

df_altered = df_original.copy()

df_altered.loc[:5,'salary_year_avg']
# Out:
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN
# 5   NaN
# Name: salary_year_avg, dtype: float64

# %%
df_altered = df_altered.dropna(subset='salary_year_avg')
df_altered.loc[:5,'salary_year_avg']
# Out:
# Series([], Name: salary_year_avg, dtype: float64)

# %%
df_original.head(5)
# Out:
#         job_title_short                                          job_title  \
# 0  Senior Data Engineer  Senior Clinical Data Engineer / Principal Clin...
# 1          Data Analyst                                       Data Analyst
# 2         Data Engineer  Data Engineer/Scientist/Analyst, Mid or Senior...
# 3         Data Engineer  LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4         Data Engineer                             Data Engineer- Sr Jobs
#
#                    job_location             job_via job_schedule_type  \
# 0                 Watertown, CT     via Work Nearby         Full-time
# 1  Guadalajara, Jalisco, Mexico    via BeBee México         Full-time
# 2               Berlin, Germany        via LinkedIn         Full-time
# 3               San Antonio, TX   via Diversity.com         Full-time
# 4                Washington, DC  via Clearance Jobs         Full-time
#
#    job_work_from_home       search_location      job_posted_date  \
# ...

# %%
df_altered.head(5)
# Out:
#     job_title_short                                job_title  \
# 28   Data Scientist                      CRM Data Specialist
# 77    Data Engineer                            Data Engineer
# 92    Data Engineer  Remote - Data Engineer - Permanent - W2
# 100  Data Scientist  Data Scientist, Risk Data Mining - USDS
# 109    Data Analyst    Senior Supply Chain Analytics Analyst
#
#                                 job_location          job_via  \
# 28   San José Province, San José, Costa Rica  via Ai-Jobs.net
# 77                             Arlington, VA     via LinkedIn
# 92                                  Anywhere     via LinkedIn
# 100                        Mountain View, CA     via LinkedIn
# 109                                 Anywhere       via Get.It
#
#     job_schedule_type  job_work_from_home            search_location  \
# 28          Full-time               False                 Costa Rica
# 77          Full-time               False                      Sudan
# ...

# %% [markdown]
# Create a new DataFrame that is a random sample of 10% of the original DataFrame. Display the first 5 rows of the sampled DataFrame. (2.3.2)
#
#     Use the sample() method to create a random sample of the DataFrame.

# %%
df.sample(frac=0.1).head(5)
#df.sample(5, frac=0.1) wouldnt work. The n and frac parameters are mutually exclusive. 
# You can specify either the number of rows (n) or the fraction of rows (frac), but not both at the same time.
# Out:
#              job_title_short                    job_title  \
# 95557         Data Scientist               Data Scientist
# 241834          Data Analyst                 Data Analyst
# 510023        Data Scientist               Data Scientist
# 746004        Data Scientist  Group Manager, Data Science
# 143140  Senior Data Engineer         Senior Data Engineer
#
#                                              job_location  \
# 95557                                      Pittsburgh, PA
# 241834  Kuala Lumpur, Federal Territory of Kuala Lumpu...
# 510023                  Makati, Metro Manila, Philippines
# 746004                                     Pittsburgh, PA
# 143140                                     Birmingham, UK
#
#                      job_via job_schedule_type  job_work_from_home  \
# 95557   via Jobs Trabajo.org         Full-time               False
# 241834       via Trabajo.org         Full-time               False
# ...

# %% [markdown]
# Create a copy of the original DataFrame and fill in missing values in the salary_year_avg column with the median salary. Display the first 5 rows of the altered DataFrame. (2.3.3)
#
#   Use the copy() method to create a copy of the DataFrame and the fillna() method to fill in missing values.

# %%
dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()

# %%
df_copy = df.copy()
df_copy.loc[:5, 'salary_year_avg']
# Out:
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN
# 5   NaN
# Name: salary_year_avg, dtype: float64

# %%
median_salary = df_copy['salary_year_avg'].median()
df_copy['salary_year_avg'] = df_copy['salary_year_avg'].fillna(median_salary)
df_copy.loc[:5, 'salary_year_avg']
# Out:
# 0    115000.0
# 1    115000.0
# 2    115000.0
# 3    115000.0
# 4    115000.0
# 5    115000.0
# Name: salary_year_avg, dtype: float64

# %%
df_copy.head()
# Out:
#         job_title_short                                          job_title  \
# 0  Senior Data Engineer  Senior Clinical Data Engineer / Principal Clin...
# 1          Data Analyst                                       Data Analyst
# 2         Data Engineer  Data Engineer/Scientist/Analyst, Mid or Senior...
# 3         Data Engineer  LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4         Data Engineer                             Data Engineer- Sr Jobs
#
#                    job_location             job_via job_schedule_type  \
# 0                 Watertown, CT     via Work Nearby         Full-time
# 1  Guadalajara, Jalisco, Mexico    via BeBee México         Full-time
# 2               Berlin, Germany        via LinkedIn         Full-time
# 3               San Antonio, TX   via Diversity.com         Full-time
# 4                Washington, DC  via Clearance Jobs         Full-time
#
#    job_work_from_home       search_location      job_posted_date  \
# ...
